# %%
import mujoco as mjc

spec = mjc.MjSpec.from_file("models/rat_hindlimb.xml")
print(spec.body('femur_l').mass)
spec.body('femur_l').mass = 0.5
spec.body('femur_l').ipos = [0.0, 0.0, 0.1]
spec.body('femur_l').inertia = [0.5, 0.5, 0.1]

print(spec.to_xml())
# Out:
# 0.02
# <mujoco model="MuJoCo Model">
#   <compiler angle="radian"/>
#
#   <default>
#     <joint limited="true" armature="1e-05" damping="0.05"/>
#   </default>
#
#   <asset>
#     <mesh name="spine" file="Geometry/spine_y2j.stl"/>
#     <mesh name="pelvis_r" file="Geometry/pelvis_r_y2j.stl"/>
#     <mesh name="femur_r" file="Geometry/femur_r_y2j.stl"/>
#     <mesh name="tibia_r" file="Geometry/tibia_r_y2j.stl"/>
#     <mesh name="foot_r" file="Geometry/foot_r_y2j.stl"/>
#     <mesh name="pelvis_l" content_type="model/stl" file="Geometry/pelvis_r_y2j.stl" scale="1 1 -1"/>
#     <mesh name="femur_l" content_type="model/stl" file="Geometry/femur_r_y2j.stl" scale="1 1 -1"/>
#     <mesh name="tibia_l" content_type="model/stl" file="Geometry/tibia_r_y2j.stl" scale="1 1 -1"/>
#     <mesh name="foot_l" content_type="model/stl" file="Geometry/foot_r_y2j.stl" scale="1 1 -1"/>
#   </asset>
#
#   <worldbody>
#     <body name="spine" quat="0.525322 0.850904 0 0">
# ...
